# %% [markdown]
# > ## Import All Libraries
#
# > # Pandas , Numpy , SKLearn , Matplotlib

# %%
import pandas as pd
import numpy as np
#!pip install pandas_profiling==3.2.0
#from pandas_profiling import ProfileReport
from sklearn.datasets import load_boston
from sklearn.metrics import mean_squared_error , mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
boston = load_boston()

# %%
print(boston.DESCR)

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
data = boston.data

# %%
target = boston.target

# %%
feature_names = boston['feature_names']

# %%
df = pd.DataFrame(data, columns = feature_names)

# %%
df['target'] = target

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
from pandas_profiling import ProfileReport

# %%
# !pip install pandas_profiling==3.2.0

# %%
# !pip install MarkupSafe==2.0.1

# %%
profile = ProfileReport(df)

# %%
profile.to_file('boston_data.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
y = df.target

# %%
x = df[['LSTAT', 'RM']]

# %%
x
# Out:
#      LSTAT     RM
# 0     4.98  6.575
# 1     9.14  6.421
# 2     4.03  7.185
# 3     2.94  6.998
# 4     5.33  7.147
# ..     ...    ...
# 501   9.67  6.593
# 502   9.08  6.120
# 503   5.64  6.976
# 504   6.48  6.794
# 505   7.88  6.030
#
# [506 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y , test_size=.2)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # fit Function in Linear Regression for Missing values

# %%
lr = LinearRegression()

# %%
lr.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# ax1 + bx2 + c #**(x1, x2) is ('LSTAT','RM')**  ->  a,b => **coef** , c =>**intercept**

# %%
lr.coef_
# Out:
# array([-0.70381835,  4.6874928 ])

# %%
lr.intercept_
# Out:
# 2.029493641826239

# %%
yhattest = lr.predict(xtest) 
#پیش بینی میکنه xtest چی باید باشه

# %% [markdown]
# حالا باید بسنجیم ببینیم چقدر درسته دیگه.
