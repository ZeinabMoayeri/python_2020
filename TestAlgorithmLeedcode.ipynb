# %%
import pandas as pd

# %%
import numpy as np

# %%
nums = [2,7,11,15]
target = 9
lis = []
for i in range(len(nums)):
    for j in range(i):
        s = nums[i] + nums[j]
        if s == target:
            lis.append(j)
            lis.append(i)

# %%
lis
# Out:
# [0, 1]

# %%
# nums = [2,7,11,15]
nums = [2,4,6]
target = 9
lis = []
for i in range(len(nums)):
    print(i)
# Out:
# 0
# 1
# 2
